# %% [markdown]
# ## Problem 1: Social Media – Post Engagement Analyzer
# ### Problem Statement
# Create a function to analyze engagement on a social media post.
# #### Rules
# - Calculate total likes
# - If Total Likes ≥ 1000 → Viral Post
# - Otherwise → Normal Engagement
# #### Real-Time Use
# - Social media analytics platforms
# - Marketing dashboards
# #### Hint
# - Use function
# - Use loop for calculations
# #### Expected Output Format
# Total Likes: 1050
#
# Post Status: Viral Post

# %%
def post_likes():

    try:
        total_likes = 0
        n = int(input("Enter number of like entries: ")) 
        
        for i in range(n): 
            like = int(input(f"Enter likes from source {i+1}: ")) 
            total_likes += like
    
        print(f"Total Likes: {total_likes}\n")

        if total_likes >= 1000:
            print(f'Post Status: Viral Post')
        else:
            print(f'Post Status: Normal Engagement')

    except ValueError:
        print("Invalid input! Please enter numbers only.")
        
post_likes()
# Out:
# Enter number of like entries:  4
# Enter likes from source 1:  150
# Enter likes from source 2:  40
# Enter likes from source 3:  351
# Enter likes from source 4:  149
# Total Likes: 690
#
# Post Status: Normal Engagement

# %% [markdown]
# ## Problem 2: Healthcare – Medicine Stock Alert System
# ### Problem Statement
# Create a function to monitor medicine stock levels.
# #### Rules
# - Stock < 10 → Low Stock Alert
# - Stock ≥ 10 → Stock Sufficient
# #### Real-Time Use
# - Pharmacy management systems
# - Hospital inventory tracking
# #### Hint
# - Use function
# - Use conditional logic
# #### Expected Output Format
# Medicine Stock: 6
#
# Status: Low Stock Alert

# %%
def stock_alert():
    stock = int(input('How much stock is available?: '))
    print(f'Medicine Stock: {stock}')

    if stock < 10:
        print(f'Status: Low Stock Alert')
    else:
        print(f'Status: Stock Sufficient')
stock_alert()
# Out:
# How much stock is available?:  1
# Medicine Stock: 1
# Status: Low Stock Alert

# %% [markdown]
# ## Problem 3: Agriculture – Rainfall Adequacy Checker
# ### Problem Statement
# Create a function that analyzes seasonal rainfall data.
# #### Rules
# - Calculate average rainfall
# - Average ≥ required level → Adequate Rainfall
# - Otherwise → Inadequate Rainfall
# #### Real-Time Use
# - Climate monitoring systems
# - Irrigation planning tools
# #### Hint
# - Use function
# - Use loop and math operations
# #### Expected Output Format
# Average Rainfall: 72
#
# Rainfall Status: Adequate Rainfall

# %%
def rainfall_analysis():
    try:
        total_rainfall = 0
        n = int(input("Enter the number seasonl entries: ")) 
        required_level = int(input('Enter the required average rainfall level: '))
        
        for i in range(n): 
            rainfall = float(input(f"Enter likes from source {i+1}: ")) 
            total_rainfall += rainfall

        average_rainfall = total_rainfall/n
        print(f"Average Rainfall: {average_rainfall}\n")

        if average_rainfall >= required_level:
            print(f'Rainfall Status: Adequate Rainfall')
        else:
            print(f'Rainfall Status: Inadequate Rainfall')

    except ValueError:
        print("Invalid input! Please enter numbers only.")

rainfall_analysis()
# Out:
# Enter the number seasonl entries:  2
# Enter the required average rainfall level:  72
# Enter likes from source 1:  12
# Enter likes from source 2:  62
# Average Rainfall: 37.0
#
# Rainfall Status: Inadequate Rainfall

# %% [markdown]
# ## Problem 4: Social Media – Duplicate Account Detection
# ### Problem Statement
# Create a function to detect duplicate usernames in a system.
# #### Rules
# - If duplicates exist → Flag accounts
# - Else → Accounts are unique
# #### Real-Time Use
# - Platform moderation
# - Fraud detection systems
# #### Hint
# - Use function
# - Use set data structure
# #### Expected Output Format
# Duplicate Accounts Found: Yes

# %%
def duplicate_accounts():
    try:
        usernames = []
        n = int(input("Enter number of usernames: "))
        
        for i in range(n):
            name = input(f"Enter username {i+1}: ")
            usernames.append(name)
        
        # Convert list to set to check uniqueness
        if len(usernames) != len(set(usernames)):
            print("Duplicate Accounts Found: Yes")
        else:
            print("Duplicate Accounts Found: No")
    
    except ValueError:
        print("Invalid input! Please enter valid values.")

duplicate_accounts()
# Out:
# Enter number of usernames:  2
# Enter username 1:  ironman
# Enter username 2:  iromnam
# Duplicate Accounts Found: No

# %% [markdown]
# ## Problem 5: Healthcare – Appointment Eligibility Checker
# ### Problem Statement
# Create a function to check whether a patient is eligible for an appointment slot.
# #### Rules
# - Age ≥ 18 → Eligible
# - Age < 18 → Not Eligible
# #### Real-Time Use
# - Hospital appointment systems
# - Healthcare portals
# #### Hint
# - Use function
# - Use condition checks
# #### Expected Output Format
# Patient Age: 21
#
# Eligibility Status: Eligible

# %%
def appointment_checker():
    try:
        age = int(input("Enter patient age: "))
        print(f"Patient Age: {age}\n")
        
        if age >= 18:
            print("Eligibility Status: Eligible")
        else:
            print("Eligibility Status: Not Eligible")
    
    except ValueError:
        print("Invalid input! Please enter a valid number.")

appointment_checker()
# Out:
# Enter patient age:  21
# Patient Age: 21
#
# Eligibility Status: Eligible

# %% [markdown]
# ## Problem 6: Agriculture – Premium Crop Price Filter
# ### Problem Statement
# Create a function that filters crop prices above a premium threshold.
# #### Rules
# - Price > ₹2000 → Premium Crop
# - Else → Regular Crop
# #### Real-Time Use
# - Market analytics
# - Export pricing systems
# #### Hint
# - Use function
# - Use list filtering logic
# #### Expected Output Format
# Premium Crops: [2500, 3200]

# %%
def premium_crop_filter():
    try:
        prices = []
        n = int(input("Enter number of crop price entries: "))
        
        for i in range(n):
            price = int(input(f"Enter price for crop {i+1}: ₹"))
            prices.append(price)
        
        # Filter premium crops using list comprehension
        premium_crops = [p for p in prices if p > 2000]
        
        print(f"Premium Crops: {premium_crops}")
    
    except ValueError:
        print("Invalid input! Please enter numeric values only.")

premium_crop_filter()
# Out:
# Enter number of crop price entries:  4
# Enter price for crop 1: ₹ 452
# Enter price for crop 2: ₹ 2500
# Enter price for crop 3: ₹ 1852
# Enter price for crop 4: ₹ 3200
# Premium Crops: [2500, 3200]

# %% [markdown]
# ## Problem 7: System Monitoring – Application Health Checker
# ### Problem Statement
# Create a function to evaluate application health based on error count.
# #### Rules
# - Errors = 0 → Healthy
# - Errors ≤ 5 → Minor Issues
# - Errors > 5 → Critical Issues
# #### Real-Time Use
# - System monitoring tools
# - IT operations dashboards
# #### Hint
# - Use function
# - Use conditional statements
# #### Expected Output Format
# Error Count: 7
#
# System Status: Critical Issues

# %%
def health_checker():
    try:
        errors = int(input("Enter error count: "))
        print(f"Error Count: {errors}\n")
        
        if errors == 0:
            print("System Status: Healthy")
        elif errors <= 5:
            print("System Status: Minor Issues")
        else:
            print("System Status: Critical Issues")
    
    except ValueError:
        print("Invalid input! Please enter a valid number.")

health_checker()
# Out:
# Enter error count:  7
# Error Count: 7
#
# System Status: Critical Issues

# %% [markdown]
# ## Problem 8: Banking – Daily Transaction Limit Checker
# ### Problem Statement
# Create a function to validate daily transaction amount.
# #### Rules
# - Daily limit = ₹50,000
# - Amount within limit → Approved
# - Amount exceeds limit → Rejected
# #### Real-Time Use
# - Banking systems
# - Fraud prevention systems
# #### Hint
# - Use function
# - Use conditional logic
# #### Expected Output Format
# Transaction Amount: 60000
#
# Transaction Status: Rejected

# %%
def transaction_checker():
    try:
        amount = int(input("Enter transaction amount: ₹"))
        print(f"Transaction Amount: {amount}\n")
        
        if amount <= 50000:
            print("Transaction Status: Approved")
        else:
            print("Transaction Status: Rejected")
    
    except ValueError:
        print("Invalid input! Please enter a valid number.")

transaction_checker()
# Out:
# Enter transaction amount: ₹ 60000
# Transaction Amount: 60000
#
# Transaction Status: Rejected

# %% [markdown]
# ## Problem 9: E-Learning – Student Attendance Eligibility System
# ### Problem Statement
# Create a function to calculate attendance percentage and check exam eligibility.
# #### Rules
# - Attendance ≥ 75% → Eligible
# - Attendance < 75% → Not Eligible
# #### Real-Time Use
# - Learning management systems
# - Internship tracking platforms
# #### Hint
# - Use function
# - Use list and loop
# #### Expected Output Format
# Attendance Percentage: 80.0
#
# Exam Eligibility: Eligible

# %%
def attendance_checker():
    try:
        total_classes = int(input("Enter total number of classes: "))
        attended_classes = []
        
        n = int(input("Enter number of attendance entries: "))
        
        for i in range(n):
            attended = int(input(f"Enter attended classes for student {i+1}: "))
            attended_classes.append(attended)
        
        # Calculate average attendance percentage
        average_attendance = (sum(attended_classes) / (total_classes * n)) * 100
        
        print(f"Attendance Percentage: {average_attendance:.1f}\n")
        
        if average_attendance >= 75:
            print("Exam Eligibility: Eligible")
        else:
            print("Exam Eligibility: Not Eligible")
    
    except ValueError:
        print("Invalid input! Please enter numeric values only.")

attendance_checker()
# Out:
# Enter total number of classes:  100
# Enter number of attendance entries:  2
# Enter attended classes for student 1:  70
# Enter attended classes for student 2:  90
# Attendance Percentage: 80.0
#
# Exam Eligibility: Eligible

# %% [markdown]
# ## Problem 10: Smart Electricity Bill Analyzer
# ### Problem Statement
# You are building a smart electricity billing system for residential users.
#
# Create a function that calculates the electricity bill and classifies usage level based on units consumed.
# #### Billing Rules
# - First 100 units → ₹3 per unit
# - Next 100 units (101–200) → ₹5 per unit
# - Above 200 units → ₹7 per unit
# #### Usage Classification
# - Total bill < ₹500 → Low Usage
# - ₹500 – ₹1500 → Moderate Usage
# - ₹1500 → High Usage
# #### Real-Time Use
# - Smart meter systems
# - Electricity board billing software
# - Energy consumption analytics
# #### Hint
# - Use function to calculate bill
# - Use conditional logic for slabs
# - Use return values (bill and usage status)

# %%
def electricity_bill():
    try:
        units = int(input("Enter units consumed: "))
        bill = 0

        # Slab calculation
        if units <= 100:
            bill = units * 3
        elif units <= 200:
            bill = (100 * 3) + ((units - 100) * 5)
        else:
            bill = (100 * 3) + (100 * 5) + ((units - 200) * 7)

        print(f"Total Bill: ₹{bill}\n")

        # Usage classification
        if bill < 500:
            print("Usage Status: Low Usage")
        elif bill <= 1500:
            print("Usage Status: Moderate Usage")
        else:
            print("Usage Status: High Usage")

        # Returning values for further use if needed
        return bill, ("Low Usage" if bill < 500 else "Moderate Usage" if bill <= 1500 else "High Usage")

    except ValueError:
        print("Invalid input! Please enter numeric values only.")
        return None, None

electricity_bill()
# Out:
# Enter units consumed:  80
# Total Bill: ₹240
#
# Usage Status: Low Usage
# (240, 'Low Usage')
